# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
data = pd.read_csv('HepCDF.csv', index_col=0)
pd.set_option('display.max_columns', None)

# %%
data.head()
# Out:
#    Age  Gender  BMI  Fever  Nausea/Vomting  Headache  Diarrhea  \
# 0   56       0   35      0               0         0         0
# 1   46       0   29      0               0         0         0
# 2   57       0   33      0               0         0         0
# 3   49       0   33      0               0         0         0
# 4   59       0   32      0               0         0         0
#
#    Fatigue & generalized bone ache  Jaundice  Epigastric pain    WBC      RBC  \
# 0                                0         0                0   7425  4248807
# 1                                0         0                0  12101  4429425
# 2                                0         0                0   4178  4621191
# 3                                0         0                0   6490  4794631
# 4                                0         0                0   3661  4606375
#
#    HGB    Plat  AST 1  ALT 1  ALT4  ALT 12  ALT 24  ALT 36  ALT 48  \
# ...

# %%
#data=pd.get_dummies(data, columns = ['Baseline histological Grading'])

# %%
#data.assign(prob=data.Gender.map(data.Gender.value_counts(normalize=True)))
# Out:
#       Age  Gender  BMI  Fever  Nausea/Vomting  Headache  Diarrhea  \
# 0      56       0   35      0               0         0         0
# 1      46       0   29      0               0         0         0
# 2      57       0   33      0               0         0         0
# 3      49       0   33      0               0         0         0
# 4      59       0   32      0               0         0         0
# ...   ...     ...  ...    ...             ...       ...       ...
# 1380   44       0   29      0               0         0         0
# 1381   55       0   34      0               0         0         0
# 1382   42       0   26      0               0         0         0
# 1383   52       0   29      0               0         0         0
# 1384   55       0   26      0               0         0         0
#
#       Fatigue & generalized bone ache  Jaundice  Epigastric pain    WBC  \
# 0                                   0         0                0   7425
# ...

# %%
z_scores = data.apply(zscore)
z_scores.head()
# Out:
#         Age  Gender       BMI  Fever  Nausea/Vomting  Headache  Diarrhea  \
# 0  1.102814     NaN  1.568525    NaN             NaN       NaN       NaN
# 1 -0.036355     NaN  0.096039    NaN             NaN       NaN       NaN
# 2  1.216730     NaN  1.077696    NaN             NaN       NaN       NaN
# 3  0.305396     NaN  1.077696    NaN             NaN       NaN       NaN
# 4  1.444564     NaN  0.832282    NaN             NaN       NaN       NaN
#
#    Fatigue & generalized bone ache  Jaundice  Epigastric pain       WBC  \
# 0                              NaN       NaN              NaN -0.040636
# 1                              NaN       NaN              NaN  1.712476
# 2                              NaN       NaN              NaN -1.257991
# 3                              NaN       NaN              NaN -0.391183
# 4                              NaN       NaN              NaN -1.451824
#
#         RBC       HGB      Plat     AST 1     ALT 1      ALT4    ALT 12  \
# ...

# %%
z_scores.dropna(axis='columns')
# Out:
#            Age       BMI       WBC       RBC       HGB      Plat     AST 1  \
# 0     1.102814  1.568525 -0.040636 -0.500596  0.824497 -1.191726  0.624437
# 1    -0.036355  0.096039  1.712476  0.021071 -1.510734 -0.747305  0.316553
# 2     1.216730  1.077696 -1.257991  0.574935 -0.343119 -0.176017  1.163233
# 3     0.305396  1.077696 -0.391183  1.075870 -1.510734 -0.306623 -1.530748
# 4     1.444564  0.832282 -1.451824  0.532143 -0.926927  0.756456  0.624437
# ...        ...       ...       ...       ...       ...       ...       ...
# 1380 -0.264188  0.096039 -0.183479  1.545332  1.408305  1.139016  1.509602
# 1381  0.988897  1.323110 -0.497285  0.620454 -1.510734 -1.097762  1.740514
# 1382 -0.492022 -0.640203 -0.982427 -0.866734  0.824497 -0.773426 -0.838010
# 1383  0.647146  0.096039 -0.103622 -0.520285 -1.510734  1.226379 -0.491641
# 1384  0.988897 -0.640203  1.611623 -1.048294  0.824497 -0.560408 -1.222864
#
#          ALT 1      ALT4    ALT 12    ALT 24    ALT 36    ALT 48  \
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'BMI', 'Fever', 'Nausea/Vomting', 'Headache',
#        'Diarrhea', 'Fatigue & generalized bone ache', 'Jaundice',
#        'Epigastric pain', 'WBC', 'RBC', 'HGB', 'Plat', 'AST 1', 'ALT 1',
#        'ALT4', 'ALT 12', 'ALT 24', 'ALT 36', 'ALT 48', 'ALT after 24 w',
#        'RNA Base', 'RNA 4', 'RNA 12', 'RNA EOT', 'RNA EF',
#        'Baseline histological Grading', 'Transplant'],
#       dtype='object')

# %%
features = ['Age', 'Gender', 'BMI', 'Fever', 'Nausea/Vomting', 'Headache',
       'Diarrhea', 'Fatigue & generalized bone ache', 'Jaundice',
       'Epigastric pain', 'WBC', 'RBC', 'HGB', 'Plat', 'AST 1', 'ALT 1',
       'ALT4', 'ALT 12', 'ALT 24', 'ALT 36', 'ALT 48', 'ALT after 24 w',
       'RNA Base', 'RNA 4', 'RNA 12', 'RNA EOT', 'RNA EF',
       'Baseline histological Grading', 'Transplant']

# %%
# Center and Scale
# preprocess the data 
from sklearn.preprocessing import StandardScaler
# Separating out the features
x = data.loc[:, features].values
# Separating out the target
y = data.loc[:,['Transplant']].values

# %%
# Standardizing the features
x = StandardScaler().fit_transform(x)

# %%
# create principal components 
from sklearn.decomposition import PCA
pca = PCA() #can specify # of components you want to return, if nothing passed, uses #of components in dataset
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2',
                                                                 'principal component 3','principal component 4',
                                                                 'principal component 5', 'principal component 6',
                                                                  'principal component 7', 'principal component 8'
                                                                 'principal component 9','principal component 10',
                                                                 'principal component 11','principal component 12',
                                                                 'principal component 13','principal component 14',
                                                                 'principal component 15','principal component 16',
                                                                 'principal component 17', 'principal component 18',
                                                                 'principal component 19', 'principal component 20',
                                                                 'principal component 21', 'principal component 22',
                                                                 'principal component 23','principal component 24',
                                                                 'principal component 25', 'principal component 26',
                                                                 'principal component 27','principal component 28',
                                                                 'principal component 29', 'principal component 30'])

# %%
pca.explained_variance_ratio_ #shows you % variance that is being explained by principal components
# Out:
# array([5.71829597e-02, 5.65655974e-02, 5.54347442e-02, 5.43368895e-02,
#        5.27011895e-02, 5.23380138e-02, 5.10303841e-02, 4.99832854e-02,
#        4.91097002e-02, 4.82761824e-02, 4.74230329e-02, 4.71931205e-02,
#        4.60398908e-02, 4.49673480e-02, 4.41064374e-02, 4.37948904e-02,
#        4.22395358e-02, 4.06206716e-02, 4.05327348e-02, 3.87164292e-02,
#        3.74069625e-02, 4.52385788e-33, 2.49298956e-33, 2.39443700e-33,
#        1.06491467e-33, 9.14256399e-34, 5.14343705e-34, 5.12536755e-35,
#        3.03182501e-35])

# %%
pca.explained_variance_ #These are the eigenvalues (eigenvalues are the distance from the projected point to the origin)
# Out:
# array([1.20170981e+00, 1.18873584e+00, 1.16497076e+00, 1.14189915e+00,
#        1.10752464e+00, 1.09989244e+00, 1.07241237e+00, 1.05040741e+00,
#        1.03204887e+00, 1.01453235e+00, 9.96603260e-01, 9.91771610e-01,
#        9.67536289e-01, 9.44996616e-01, 9.26904431e-01, 9.20357217e-01,
#        8.87671170e-01, 8.53650458e-01, 8.51802450e-01, 8.13632474e-01,
#        7.86113803e-01, 9.50696578e-32, 5.23906079e-32, 5.03195087e-32,
#        2.23793665e-32, 1.92132568e-32, 1.08090221e-32, 1.07710488e-33,
#        6.37143284e-34])

# %%
principalDf.iloc[:,:30].head()
# Out:
#    principal component 1  principal component 2  principal component 3  \
# 0               0.272155              -0.723275              -0.521623
# 1               1.163900              -1.425676               0.423275
# 2              -1.925559               0.396737               0.769331
# 3              -1.034793              -0.647550               0.414438
# 4               4.799068               3.795846              -0.812504
#
#    principal component 4  principal component 5  principal component 6  \
# 0              -0.283323              -1.225830               0.703959
# 1               0.189286               0.506033               1.789895
# 2               0.097948               1.803242               0.936882
# 3              -0.826100               1.259446              -0.372251
# 4              -0.016625               6.320774               4.034442
#
#    principal component 7  principal component 8principal component 9  \
# ...

# %%
eig_values = pca.explained_variance_
eig_vectors = pca.components_
print(eig_values)
print(eig_vectors)
# Out:
# [1.20170981e+00 1.18873584e+00 1.16497076e+00 1.14189915e+00
#  1.10752464e+00 1.09989244e+00 1.07241237e+00 1.05040741e+00
#  1.03204887e+00 1.01453235e+00 9.96603260e-01 9.91771610e-01
#  9.67536289e-01 9.44996616e-01 9.26904431e-01 9.20357217e-01
#  8.87671170e-01 8.53650458e-01 8.51802450e-01 8.13632474e-01
#  7.86113803e-01 9.50696578e-32 5.23906079e-32 5.03195087e-32
#  2.23793665e-32 1.92132568e-32 1.08090221e-32 1.07710488e-33
#  6.37143284e-34]
# [[ 7.79815429e-02  8.32667268e-17  1.16337266e-01 -5.55111512e-17
#    1.11022302e-16 -0.00000000e+00 -0.00000000e+00 -5.55111512e-17
#    2.77555756e-17  1.38777878e-17 -9.22886150e-02 -2.09753455e-01
#   -1.23900587e-01  2.16710662e-01  1.60349687e-01  4.86973899e-01
#   -2.44350275e-01 -2.18000232e-01 -3.39636177e-01 -1.08351395e-01
#    4.19221930e-01 -7.80394860e-02  7.98023043e-02 -6.59352305e-02
#    2.32741376e-01 -2.87899582e-01 -1.30449937e-01  1.27666996e-01
#   -7.38418580e-02]
# ...

# %%
# examine the components
pc1 = pca.components_[0]
pc2 = pca.components_[1]
pc3 = pca.components_[2]
pc4 = pca.components_[3]
pc5 = pca.components_[4]
pc6 = pca.components_[5]
pc7 = pca.components_[6]
pc8 = pca.components_[7]
pc9 = pca.components_[8]
pc10 = pca.components_[9]
pc11 = pca.components_[10]
pc12 = pca.components_[11]
pc13 = pca.components_[12]
pc14 = pca.components_[13]
pc15= pca.components_[14]
pc16= pca.components_[15]
pc17= pca.components_[16]
pc18= pca.components_[17]
pc19= pca.components_[18]
pc20= pca.components_[19]
pc21= pca.components_[20]
pc22= pca.components_[21]
pc23= pca.components_[22]
pc24= pca.components_[23]
pc25= pca.components_[24]
pc26= pca.components_[25]
pc27= pca.components_[26]
pc28= pca.components_[27]
pc29= pca.components_[28]

# the .components attribute shows principal axes in feature space, representing the directions of maximum variance in the data. 
#The components are sorted by explained_variance_

# %%
print(pc1)
print(pc2)
print(pc3)
print(pc4)
print(pc5)
print(pc6)
print(pc7)
print(pc8)
print(pc9)
print(pc10)
print(pc11)
print(pc12)
print(pc13)
print(pc14)
print(pc15)
print(pc16)
print(pc17)
print(pc18)
print(pc19)
print(pc20)
print(pc21)
print(pc22)
print(pc23)
print(pc24)
print(pc25)
print(pc26)
print(pc27)
print(pc28)
print(pc29)
# Out:
# [ 7.79815429e-02  8.32667268e-17  1.16337266e-01 -5.55111512e-17
#   1.11022302e-16 -0.00000000e+00 -0.00000000e+00 -5.55111512e-17
#   2.77555756e-17  1.38777878e-17 -9.22886150e-02 -2.09753455e-01
#  -1.23900587e-01  2.16710662e-01  1.60349687e-01  4.86973899e-01
#  -2.44350275e-01 -2.18000232e-01 -3.39636177e-01 -1.08351395e-01
#   4.19221930e-01 -7.80394860e-02  7.98023043e-02 -6.59352305e-02
#   2.32741376e-01 -2.87899582e-01 -1.30449937e-01  1.27666996e-01
#  -7.38418580e-02]
# [ 2.27681000e-02 -1.38777878e-17 -3.04800409e-01  4.16333634e-17
#   5.55111512e-17 -3.46944695e-17 -2.08166817e-17  6.93889390e-18
#  -2.77555756e-17  8.32667268e-17 -3.32560702e-01  1.28920947e-01
#  -8.99417574e-03  2.23720789e-01  4.13819924e-02  3.57022587e-02
#  -7.13778120e-02  1.80960267e-01  2.38134777e-01  2.78477744e-01
#  -7.74383612e-02 -2.59562669e-01 -1.71990863e-01 -4.92194990e-01
#   2.21037918e-01 -2.22555747e-01  2.79241041e-01  1.12087759e-01
#   1.41450907e-01]
# ...

# %%
# get the loadings
structure_loading_1 = pc1* np.sqrt(eig_values[0])
str_loading_1 = pd.Series(structure_loading_1, index=features)
str_loading_1
#first 4 vary in same direction, acceleration varies in the opposite direction (can interpret as magnitude and direction, numbers don't mean much since they're recentered around origin, not very interpretable)
# Out:
# Age                                8.548534e-02
# Gender                             9.127909e-17
# BMI                                1.275318e-01
# Fever                             -6.085273e-17
# Nausea/Vomting                     1.217055e-16
# Headache                          -0.000000e+00
# Diarrhea                          -0.000000e+00
# Fatigue & generalized bone ache   -6.085273e-17
# Jaundice                           3.042636e-17
# Epigastric pain                    1.521318e-17
# WBC                               -1.011691e-01
# RBC                               -2.299370e-01
# HGB                               -1.358230e-01
# Plat                               2.375637e-01
# AST 1                              1.757794e-01
# ALT 1                              5.338331e-01
# ALT4                              -2.678629e-01
# ALT 12                            -2.389774e-01
# ALT 24                            -3.723178e-01
# ALT 36                            -1.187775e-01
# ...

# %%
str_loading_1.sort_values(ascending=False)
# Out:
# ALT 1                              5.338331e-01
# ALT 48                             4.595617e-01
# RNA 12                             2.551370e-01
# Plat                               2.375637e-01
# AST 1                              1.757794e-01
# Baseline histological Grading      1.399518e-01
# BMI                                1.275318e-01
# RNA Base                           8.748130e-02
# Age                                8.548534e-02
# Nausea/Vomting                     1.217055e-16
# Gender                             9.127909e-17
# Jaundice                           3.042636e-17
# Epigastric pain                    1.521318e-17
# Headache                          -0.000000e+00
# Diarrhea                          -0.000000e+00
# Fever                             -6.085273e-17
# Fatigue & generalized bone ache   -6.085273e-17
# RNA 4                             -7.227986e-02
# Transplant                        -8.094731e-02
# ALT after 24 w                    -8.554886e-02
# ...

# %%
index = np.arange(29)
plt.bar(index, pca.explained_variance_ratio_)
plt.title('Scree plot for PCA')
plt.xlabel('Num of components')
plt.ylabel('proportion of explained variance')
#scree plot shows you where dropoff occurs
# Out:
# Text(0, 0.5, 'proportion of explained variance')

# %%
# plotting screeplots 
#print(pca.explained_variance_ratio_)
#print(pca.explained_variance_)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('explained variance ratio')
# Out:
# Text(0, 0.5, 'explained variance ratio')
