# %%
import pandas as pd

# %%
# monster_data1 = pd.read_csv('2017_dem.csv')
# monster_data1
# Out:
#          GEO.id GEO.id2     GEO.display-label POPGROUP.id  \
# 0            Id     Id2             Geography          Id
# 1   0400000US01      01               Alabama         001
# 2   0400000US02      02                Alaska         001
# 3   0400000US04      04               Arizona         001
# 4   0400000US05      05              Arkansas         001
# 5   0400000US06      06            California         001
# 6   0400000US08      08              Colorado         001
# 7   0400000US09      09           Connecticut         001
# 8   0400000US10      10              Delaware         001
# 9   0400000US11      11  District of Columbia         001
# 10  0400000US12      12               Florida         001
# 11  0400000US13      13               Georgia         001
# 12  0400000US15      15                Hawaii         001
# 13  0400000US16      16                 Idaho         001
# 14  0400000US17      17              Illinois         001
# ...

# %%
monster_data = pd.read_csv('2016_dem.csv')
monster_data.columns = monster_data.iloc[0]

# %%
monster_data = monster_data[1:]

# %%
monster_data
# Out:
# 0            Id Id2             Geography   Id  Population Group  \
# 1   0400000US01  01               Alabama  001  Total population
# 2   0400000US02  02                Alaska  001  Total population
# 3   0400000US04  04               Arizona  001  Total population
# 4   0400000US05  05              Arkansas  001  Total population
# 5   0400000US06  06            California  001  Total population
# 6   0400000US08  08              Colorado  001  Total population
# 7   0400000US09  09           Connecticut  001  Total population
# 8   0400000US10  10              Delaware  001  Total population
# 9   0400000US11  11  District of Columbia  001  Total population
# 10  0400000US12  12               Florida  001  Total population
# 11  0400000US13  13               Georgia  001  Total population
# 12  0400000US15  15                Hawaii  001  Total population
# 13  0400000US16  16                 Idaho  001  Total population
# ...

# %%
monster_data.columns.str.startswith('Margin')
monster_data = monster_data.loc[:,~monster_data.columns.str.startswith('Margin')]

# %%
monster_data.drop(['Id', 'Id2', 'Id', 'Population Group'], axis=1, inplace=True)
# Out:
# /Users/brittanyfowle/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
monster_data = monster_data.T

# %%
monster_data.index
# Out:
# Index(['Geography',
#        'Estimate; TOTAL NUMBER OF RACES REPORTED - Total population',
#        'Estimate; TOTAL NUMBER OF RACES REPORTED - Total population - One race',
#        'Estimate; TOTAL NUMBER OF RACES REPORTED - Total population - Two races',
#        'Estimate; TOTAL NUMBER OF RACES REPORTED - Total population - Three races',
#        'Estimate; TOTAL NUMBER OF RACES REPORTED - Total population - Four or more races',
#        'Estimate; SEX AND AGE - Total population',
#        'Estimate; SEX AND AGE - Total population - Male',
#        'Estimate; SEX AND AGE - Total population - Female',
#        'Estimate; SEX AND AGE - Under 5 years',
#        ...
#        'Estimate; OWNER CHARACTERISTICS - Owner-occupied housing units - Median selected monthly owner costs with a mortgage (dollars)',
#        'Estimate; OWNER CHARACTERISTICS - Owner-occupied housing units - Median selected monthly owner costs without a mortgage (dollars)',
# ...

# %%
monster_cols = [col for col in monster_data.index if 'Median family income' in col]
print(monster_cols)
# Out:
# ['Estimate; INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Families - Median family income (dollars)', 'Estimate; INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Families - Median family income (dollars) - Married-couple family']

# %%
monster_data = monster_data.T

# %%
cols = ['Estimate; INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Families - Median family income (dollars)']

# %%
df = monster_data[cols]

# %%
df
# Out:
# 0  Estimate; INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Families - Median family income (dollars)
# 1                                               59764
# 2                                               88604
# 3                                               63877
# 4                                               55484
# 5                                               77359
# 6                                               80761
# 7                                               94449
# 8                                               74251
# 9                                               98498
# 10                                              61289
# 11                                              65018
# 12                                              86768
# 13                                              63182
# 14                                              76950
# 15                                              66032
# ...
